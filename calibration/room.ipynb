# %%
import numpy as np
import json
import math
import matplotlib.pyplot as plt
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D

# %%
points = [(5.380,3.435,1.771),(2.246,3.618,1.616),(2.450,4.893,1.642),(3.637,4.222,1.636),(2.638,3.315,1.648),(2.231,2.823,1.666),(1.662,5.343,1.549)]
ground = [(5.336, 3.372,1.67),(2.280, 3.396,1.67),(2.346, 4.922,1.67),(3.644, 4.201,1.67),(2.601, 3.350,1.67),(2.159, 2.842,1.67),(1.592, 5.276,1.67)]

# %%
x = []
y = []
for i in range(0,len(points)):
    x.append(points[i][0])
    y.append(points[i][1])
X = []
Y = []
for i in range(0,len(points)):
    X.append(ground[i][0])
    Y.append(ground[i][1])
wallx = [0,7.102,7.102,0,0]
wally = [0,0,7.355,7.355,0]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,'-*',label='computed route')
ax.plot(X,Y,'-o',label='ground truth route')
ax.plot(wallx,wally,'--k', label='wall')
ax.legend(loc='upper left')
plt.xlim(-0.5,7.5)
plt.ylim(-0.5,8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = []
y = []
z = []
for i in range(0,len(points)):
    x.append(points[i][0])
    y.append(points[i][1])
    z.append(points[i][2])
    
X = []
Y = []
Z = []
for i in range(0,len(points)):
    X.append(ground[i][0])
    Y.append(ground[i][1])
    Z.append(ground[i][2])
    
wallx = [0,7.102,7.102,0,0]
wally = [0,0,7.355,7.355,0]
wallz = [0,0,0,0,0]

fig = plt.figure()
ax = Axes3D(fig)
ax.plot(x,y,z,'-*',label='computed route')
ax.plot(X,Y,Z,'-.',label='ground truth route')
ax.legend(loc='upper left')
plt.xlim(1,5,5)
plt.ylim(2.5,5.5)
ax.set_zlim(1,2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
