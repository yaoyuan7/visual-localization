# %%
import numpy as np
import json
import math
import matplotlib.pyplot as plt
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D

# %%
ground = [(5.368, 3.404, 1.67), (2.248, 3.61, 1.67), (2.374, 4.929, 1.67), (3.673, 4.223, 1.67), (2.623, 3.309, 1.67), (2.176, 2.792, 1.67), (1.558, 5.307, 1.67)]
point_mds = [(5.38,3.435,1.771),(2.249,3.622,1.537),(2.459,4.913,1.857),(3.664,4.216,1.688),(2.638,3.306,1.761),(2.229,2.795,1.778),(1.655,5.358,0.992)]
point_srls = [(5.381,3.439,1.686),(2.234,3.623,1.592),(2.452,4.922,1.733),(3.661,4.226,1.67),(2.631,3.305,1.744),(2.219,2.796,1.726),(1.636,5.375,1.524)]

# %%
mse = [(0.092,0.106,0.041),(0.208,0.134,0.080),(0.151,0.206,0.1),(0.075,0.021,0.012),(0.038,0.093,0.075),(0.041,0.121,0.071),(0.028,0.686,0.179)]
err = [(1.41,1.62,0.62),(4.72,2.93,1.75),(2.65,3.61,1.75),(1.29,0.36,0.21),(0.83,2.04,1.65),(1.05,3.08,1.81),(0.49,11.89,3.09)]

# %%
x = [1,2,3,4,5,6,7]
y1 = []
y2 =[]
y3 = []

for i in range(0,len(mse)):
    y1.append(mse[i][0])
    y2.append(mse[i][1])
    y3.append(mse[i][2])
    
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y1,'-*',label='RMSE(LS)')
ax.plot(x,y2,'-o',label='RMSE(MDS)')
ax.plot(x,y3,'-.',label='RMSE(SRLS)')

ax.legend(loc='upper left')
plt.xlim(0.5,7.5)
plt.ylim(-0.1,0.8)
plt.show()

x = [1,2,3,4,5,6,7]
z1 = []
z2 =[]
z3 = []

for i in range(0,len(err)):
    z1.append(err[i][0])
    z2.append(err[i][1])
    z3.append(err[i][2])
    
z1 = [x/100 for x in z1]
z2 = [x/100 for x in z2]
z3 = [x/100 for x in z3]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,z1,'-*',label='error ratio (LS)')
ax.plot(x,z2,'-o',label='error ratio (MDS)')
ax.plot(x,z3,'-.',label='error ratio (SRLS)')

ax.legend(loc='upper left')
plt.xlim(0.5,7.5)
plt.ylim(-0.01,0.125)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
x = []
y = []
for i in range(0,len(point_mds)):
    x.append(point_mds[i][0])
    y.append(point_mds[i][1])
X = []
Y = []
for i in range(0,len(point_srls)):
    X.append(point_srls[i][0])
    Y.append(point_srls[i][1])
xx = []
yy = []
for i in range(0,len(ground)):
    xx.append(ground[i][0])
    yy.append(ground[i][1])
    
wallx = [0,7.074,7.074,0,0]
wally = [0,0,7.355,7.355,0]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,'-*',label='computed location(MDS)')
ax.plot(X,Y,'-o',label='computed location(SRLS)')
ax.plot(xx,yy,'-.',label='ground truth route')
ax.plot(wallx,wally,'--k', label='wall')
ax.legend(loc='upper left')
plt.xlim(-0.5,7.5)
plt.ylim(-0.5,8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = []
y = []
z = []
for i in range(0,len(point_mds)):
    x.append(point_mds[i][0])
    y.append(point_mds[i][1])
    z.append(point_mds[i][2])
    
X = []
Y = []
Z = []
for i in range(0,len(point_srls)):
    X.append(point_srls[i][0])
    Y.append(point_srls[i][1])
    Z.append(point_srls[i][2])
    
xx = []
yy = []
zz = []
for i in range(0,len(ground)):
    xx.append(ground[i][0])
    yy.append(ground[i][1])
    zz.append(ground[i][2])
wallx = [0,7.102,7.102,0,0]
wally = [0,0,7.355,7.355,0]
wallz = [0,0,0,0,0]

fig = plt.figure()
ax = Axes3D(fig)
ax.plot(x,y,z,'-*',label='computed route (MDS)')
ax.plot(X,Y,Z,'-o',label='computed route(SRLS)')
ax.plot(xx,yy,zz,'-.',label='ground truth route')

ax.legend(loc='upper left')
plt.xlim(7.5,0)
plt.ylim(7.5,0)
ax.set_zlim(0,2)
#ax.view_init(azim=90, elev=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
